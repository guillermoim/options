# %%
#%matplotlib widget
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0, '..')
import pickle
from matplotlib.ticker import FormatStrFormatter
import matplotlib.pyplot as plt
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
plt.ioff()

# %%
mean_rewards = np.loadtxt('results/rooms_mean_rewards_3x3.txt')
errors0 = np.loadtxt('results/rooms_Flat_errors_3x3.txt')
errors1 = np.loadtxt('results/rooms_Flat_errors_lr04_eps03fixed.txt')
errors2 = np.loadtxt('results/rooms_Flat_errors_lr09_eps03fixed.txt')
errors3 = np.loadtxt('results/rooms_Flat_errors_lr04_eps01fixed.txt')
errors4 = np.loadtxt('results/rooms_Flat_errors_dynamiclr_0.1eps.txt')
errors5 = np.loadtxt('results/rooms_Flat_errors_dynamiclr_03eps.txt')
errors6 = np.loadtxt('results/rooms_options_errors_current.txt')
errors7 = np.loadtxt('results/rooms_options_errors_dynamic_fixedLL04.txt')
errors8 = np.loadtxt('results/rooms_options_errors_dynamic_LLgreedy.txt')
errors9 = np.loadtxt('results/rooms_options_errors_HL07_LL03.txt')
errors10 = np.loadtxt('results/rooms_options_errors_o_HL07_LL03.txt')


#filename = 'pictures/overall_taxi_5_1.pdf'
csfont = {'fontname':'Helvetica', 'fontsize':26}
hfont = {'fontname':'Helvetica', 'fontsize':26}

plt.close('all')

fig, ax = plt.subplots(1,1, figsize=(9, 6))

lambda_ = 1

ax.set_title(fr'TD-learning', **csfont)
       
#ax.plot(mean_rewards, linewidth=3, markevery=250, color='gray', marker='x', markersize=10)
#ax.plot(errors, linewidth=3, markevery=250, color='brown', marker='d', markersize=10)
#ax.plot(errors1, linewidth=3, markevery=250, color='orange', marker='x', markersize=10)
#ax.plot(errors2, linewidth=3, markevery=250, color='blue', marker='v', markersize=10)
#ax.plot(errors3, linewidth=3, markevery=250, color='green', marker='o', markersize=10)
ax.plot(errors4, linewidth=3, markevery=250, color='salmon', marker='o', markersize=10)
#ax.plot(errors5, linewidth=3, markevery=250, color='yellow', marker='o', markersize=10)
ax.plot(errors6, linewidth=3, markevery=250, color='red', marker='o', markersize=10)
#ax.plot(errors7, linewidth=3, markevery=250, color='blue', marker='o', markersize=10)
#ax.plot(errors8, linewidth=3, markevery=250, color='green', marker='x', markersize=10)
#ax.plot(errors9, linewidth=3, markevery=250, color='yellow', marker='x', markersize=10)
ax.plot(errors10, linewidth=3, markevery=250, color='cyan', marker='x', markersize=10)

plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))

legend = ['flat-TD', 'options', 'IL-error']

ax.legend(legend, fontsize=22)
ax.set_xlim((0,60000))
ax.set_ylim((0,15))

ax.tick_params(axis='both', which='major', labelsize=18)
ax.tick_params(axis='both', which='minor', labelsize=18)
ax.xaxis.offsetText.set_fontsize(18)

ax.set_ylabel('MAE in $\hat V(s)$', **hfont)
ax.set_xlabel('samples', **hfont)

#plt.savefig(filename, bbox_inches='tight', dpi=500)
plt.show()
