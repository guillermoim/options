# %%
#%matplotlib widget
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0, '..')

from results_functions import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
results_dir = '../results'

# %% [markdown]
# # <span style="color: red;"> High-level MAE evolution with number of samples</span>

# %%
res_v1 = get_MAE_HL_errors(f'{results_dir}/6_6_v1_333.pkl', '$V_1$-IL', 10000, 80, (11, 9))

# %%
res_v2 = get_MAE_HL_errors(f'{results_dir}/6_6_v2_000.pkl', '$V_2$-IL (subtasks provided)', 10000, 80, (11, 9))

# %%
res_v2 = get_MAE_HL_errors(f'{results_dir}/3_3_v2_333.pkl', '$V_2$-IL (subtasks provided)', 10000, 30, (11, 9))

# %%
res_v3 = get_MAE_HL_errors(f'{results_dir}/6_6_v3_000.pkl', '$V_3$-IL', 10000, 80, (11, 9))

# %%
res_plain = get_MAE_plain_Z_learning(f'{results_dir}/6_6_flat_000.pkl', 'Z-learning+IS', 10000, 100)

# %% [markdown]
# # <span style="color: blue;"> Low-level MAE evolution with number of samples</span>

# %%
get_MAE_LL_errors(f'{results_dir}/6_6_v1_333.pkl', 'Subtask MAE $V_1$', 750, 10)

# %%
get_MAE_LL_errors(f'{results_dir}/3_3_v2_333.pkl', 'Subtask MAE $V_2$', 750, 6)

# %%
get_MAE_LL_errors(f'{results_dir}/3_3_v3_333.pkl', 'Subtask MAE $V_3$', 750, 6)

# %% [markdown]
# # <span style="color: orange;"> Results combination</span>

# %%
fig, ax = plt.subplots(1,1)

ax.set_title('MAE of $\hat V(s) = \log \hat Z(s)$')
       
ax.plot(res_v1[2], linewidth=1, markevery=500, color='gray', marker='x')
ax.plot(res_v2[2], linewidth=1, markevery=500, color='brown', marker='x')
ax.plot(res_v3[2], linewidth=1, markevery=500, color='royalblue', marker='^')
ax.plot(res_plain, linewidth=1, markevery=500, color='black', marker='o')

legend = ['$V_1$', '$V_2$', '$V_3$', 'Z-IS']

ax.legend(legend)
ax.set_xlim((0,10000))
ax.set_ylim((0,80))

ax.set_ylabel('error')
ax.set_xlabel('samples')
# Out:
# Text(0.5, 0, 'samples')

# %%
Z0 = res_v1[0]
plotmat(np.log(Z0[:900]).reshape(30,30), '$\hat V(s)$ v$_1$', annotated=True, figsize=(17,17))
plt.show()

# %%
Z0 = res_v3[0]
plotmat(np.log(Z0[:225]).reshape(15,15), '$\hat V(s)$ v$_3$', annotated=True, figsize=(9,9))
plt.show()

# %%
Z_true = pickle.load(open('../configurations/3_3.dict', 'rb'))['Z_true']
plotmat(np.log(Z_true[:225]).reshape(15,15), 'TRUE', annotated=True, figsize=(9,9))
plt.show()
